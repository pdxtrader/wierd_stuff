# %%
from    coinapi_v1 import CoinAPIv1
import  datetime
from    datetime  import date
from    datetime  import datetime
from    datetime  import timedelta
from    tqdm      import tqdm

test_key      =  'B77ED0B6-F44D-4186-A6BB-5AB92FAA3793'

api           = None
exchanges     = None
assets        = None
symbols       = None
periods       = None

asset_ids     = []
exchange_ids  = []
symbol_ids    = []
period_ids    = []

start_of_2015              = date(2015, 1, 1)
start_of_2016              = date(2016, 1, 1)
start_of_2017              = date(2017, 1, 1)
start_of_2018              = date(2018, 1, 1)
datetime__now              = datetime.now()
datetime__now_iso          = datetime__now.isoformat()
date__today                = date.today()
date__today_iso            = date__today.isoformat()
date__yesterday            = date__today - timedelta(1)
date__two_days_ago         = date__today - timedelta(2)
date__three_days_ago       = date__today - timedelta(3)
date__four_days_ago        = date__today - timedelta(4)
date__five_days_ago        = date__today - timedelta(5)
date__six_days_ago         = date__today - timedelta(6)
date__week_ago             = date__today - timedelta(7)
date__mounth_ago           = date__today - timedelta(30)
datetime__now              = datetime.now()
datetime__yesterday        = datetime__now - timedelta(1)
datetime__two_days_ago     = datetime__now - timedelta(2)
datetime__three_days_ago   = datetime__now - timedelta(3)
datetime__four_days_ago    = datetime__now - timedelta(4)
datetime__five_days_ago    = datetime__now - timedelta(5)
datetime__six_days_ago     = datetime__now - timedelta(6)
datetime__week_ago         = datetime__now - timedelta(7)
datetime__mounth_ago       = datetime__now - timedelta(30)
datetime__hour_ago         = datetime__now - timedelta(hours = 1)
datetime__two_hours_ago    = datetime__now - timedelta(hours = 2)
datetime__three_hours_ago  = datetime__now - timedelta(hours = 3)
datetime__six_hours_ago    = datetime__now - timedelta(hours = 6)
datetime__twelve_hours_ago = datetime__now - timedelta(hours = 12)


def update_ids():
    global assets
    global exchanges
    global symbols
    global periods
    global asset_ids
    global exchange_ids
    global symbol_ids
    global period_ids
    for ii in tqdm(range(0, 4), desc=  '[Updating _ids variables                ]'):
        if ii == 0:
            for asset in assets:
                asset_ids.append(asset['asset_id'])
        if ii == 1:
            for exchange in exchanges:
                exchange_ids.append(exchange['exchange_id'])
        if ii == 2:
            for symbol in symbols:
                symbol_ids.append(symbol['symbol_id'])
        if ii == 3:
            for period in periods:
                period_ids.append(period['period_id'])

def update_coinapi():
    global api 
    global exchanges
    global assets
    global symbols
    global periods
    for ii in tqdm(range(0, 5),desc = '[Updating Meta Data from Coinapi        ]' ):    
        if ii == 0:
            api           = CoinAPIv1(test_key)
        elif ii == 1:
            exchanges     = api.metadata_list_exchanges()
        elif ii == 2:
            assets        = api.metadata_list_assets()
        elif ii == 3:
            symbols       = api.metadata_list_symbols()
        elif ii == 4:
            periods       = api.ohlcv_list_all_periods()

def update_time():
    global datetime__now             
    global datetime__now_iso          
    global date__today                
    global date__today_iso            
    global date__today
    global date__yesterday            
    global date__two_days_ago         
    global date__three_days_ago      
    global date__four_days_ago      
    global date__five_days_ago      
    global date__six_days_ago       
    global date__week_ago           
    global date__mounth_ago       
    global datetime__now           
    global datetime__yesterday       
    global datetime__two_days_ago     
    global datetime__three_days_ago  
    global datetime__four_days_ago   
    global datetime__five_days_ago  
    global datetime__six_days_ago    
    global datetime__week_ago        
    global datetime__mounth_ago    
    global datetime__hour_ago         
    global datetime__two_hours_ago  
    global datetime__three_hours_ago 
    global datetime__six_hours_ago   
    global datetime__twelve_hours_ago    
    for ii in tqdm(range(0,28), desc='[Updating time related variables        ]'):
        if ii == 0:
            datetime__now              = datetime.now()
        elif ii == 1:
            datetime__now_iso          = datetime__now.isoformat()
        elif ii == 2:
            datetime__now_iso          = datetime__now.isoformat()       
        elif ii == 3:
            datetime__now_iso          = datetime__now.isoformat()
        elif ii == 4:
             date__today                = date.today()
        elif ii == 5:
            date__today_iso            = date__today.isoformat()
        elif ii == 6:
            date__yesterday            = date__today - timedelta(1)
        elif ii == 7:
            date__two_days_ago         = date__today - timedelta(2) 
        elif ii == 8:
            date__three_days_ago       = date__today - timedelta(3)
        elif ii == 9:
            date__four_days_ago        = date__today - timedelta(4)
        elif ii == 10:
            date__five_days_ago        = date__today - timedelta(5)
        elif ii == 11:
            date__six_days_ago         = date__today - timedelta(6)
        elif ii == 12:
            date__week_ago             = date__today - timedelta(7)
        elif ii == 13:
            date__mounth_ago           = date__today - timedelta(30)
        elif ii == 14:
            datetime__now              = datetime.now()
        elif ii == 15:
            datetime__yesterday        = datetime__now - timedelta(1)
        elif ii == 16:
            datetime__two_days_ago     = datetime__now - timedelta(2)
        elif ii == 17:
            datetime__three_days_ago   = datetime__now - timedelta(3)
        elif ii == 18:
            datetime__four_days_ago    = datetime__now - timedelta(4)
        elif ii == 19:
            datetime__five_days_ago    = datetime__now - timedelta(5)
        elif ii == 20:
            datetime__six_days_ago     = datetime__now - timedelta(6)
        elif ii == 21:
            datetime__week_ago         = datetime__now - timedelta(7)
        elif ii == 22:
            datetime__mounth_ago       = datetime__now - timedelta(30)
        elif ii == 23:
            datetime__hour_ago         = datetime__now - timedelta(hours = 1)
        elif ii == 24:
            datetime__two_hours_ago    = datetime__now - timedelta(hours = 2)
        elif ii == 25:
            datetime__three_hours_ago  = datetime__now - timedelta(hours = 3)
        elif ii == 26:
            datetime__six_hours_ago    = datetime__now - timedelta(hours = 6)
        elif ii == 27:
            datetime__twelve_hours_ago = datetime__now - timedelta(hours = 12)    
                  
def update_all():
    for ii in tqdm(range(0, 3),desc = '[Updating all                           ]' ):    
        if ii == 0:
            update_coinapi()             
        elif ii == 1:
            update_ids()
        elif ii == 3:
            update_time()
    
def current_exchange_rate(asset_1, asset_2):
    from datetime import date
    global api
    result = {}
    return api.exchange_rates_get_specific_rate(asset_1, asset_2)

def exchange_rate(asset_1, asset_2, exchange_date = date.today()):
    from datetime import date
    global api
    exchange_date_iso = exchange_date.isoformat()
    return api.exchange_rates_get_specific_rate(str(asset_1), str(asset_2), {'time': exchange_date_iso})

def all_current_exchange_rates(asset_1):
    global api
    return api.exchange_rates_get_all_current_rates(asset_1)

# %%
# testing update_all() situation
update_all()
print(str(datetime__now) + '  '  + str(datetime__three_hours_ago))
# print(asset_ids)
print(datetime__now) 
print(api)
# seems ok
# Out:
# [Updating all                           ]:   0%|          | 0/3 [00:00<?, ?it/s]
# [Updating Meta Data from Coinapi        ]:   0%|          | 0/5 [00:00<?, ?it/s]
# [Updating Meta Data from Coinapi        ]:  40%|████      | 2/5 [00:00<00:00,  7.17it/s]
# [Updating Meta Data from Coinapi        ]:  60%|██████    | 3/5 [00:00<00:00,  3.73it/s]
# [Updating Meta Data from Coinapi        ]:  80%|████████  | 4/5 [00:04<00:01,  1.07s/it]
# [Updating Meta Data from Coinapi        ]: 100%|██████████| 5/5 [00:04<00:00,  1.12it/s]
# [Updating all                           ]:  33%|███▎      | 1/3 [00:04<00:08,  4.47s/it]
# [Updating _ids variables                ]:   0%|          | 0/4 [00:00<?, ?it/s]
# [Updating all                           ]: 100%|██████████| 3/3 [00:04<00:00,  1.49s/it]]
# 2018-03-25 15:08:32.529436  2018-03-25 12:08:32.529436
# 2018-03-25 15:08:32.529436
# <coinapi_v1.CoinAPIv1 object at 0x7ff7c0cfef60>

# %%
print(current_exchange_rate('BTC', 'USD'))
print(current_exchange_rate('ETH', 'USD'))
print(current_exchange_rate('XRP', 'USD'))
print(current_exchange_rate('LTC', 'USD'))
print(current_exchange_rate('USDT', 'USD'))

print(exchange_rate('BTC', 'USD',  exchange_date = date(2017,5,16)))
print(exchange_rate('ETH', 'USD',  exchange_date = date(2017,5,16)))
print(exchange_rate('XRP', 'USD',  exchange_date = date(2017,5,16)))
print(exchange_rate('LTC', 'USD',  exchange_date = date(2017,5,16)))
print(exchange_rate('USDT', 'USD', exchange_date = date(2017,5,16)))

a = date(2017,11,20)
print(exchange_rate('BTC', 'USD',  exchange_date = a))
print(exchange_rate('ETH', 'USD',  exchange_date = a))
print(exchange_rate('XRP', 'USD',  exchange_date = a))
print(exchange_rate('LTC', 'USD',  exchange_date = a))
print(exchange_rate('USDT', 'USD', exchange_date = a))
# Out:
# {'time': '2018-03-25T13:35:43.1245570Z', 'asset_id_base': 'BTC', 'asset_id_quote': 'USD', 'rate': 8506.709669848075}
# {'time': '2018-03-25T13:35:43.2808052Z', 'asset_id_base': 'ETH', 'asset_id_quote': 'USD', 'rate': 519.5718490062168}
# {'time': '2018-03-25T13:35:43.2183092Z', 'asset_id_base': 'XRP', 'asset_id_quote': 'USD', 'rate': 0.6299179713157843}
# {'time': '2018-03-25T13:35:43.5933027Z', 'asset_id_base': 'LTC', 'asset_id_quote': 'USD', 'rate': 158.93312445196568}
# {'time': '2018-03-25T13:35:19.6747062Z', 'asset_id_base': 'USDT', 'asset_id_quote': 'USD', 'rate': 1.0009}
# {'time': '2017-05-15T23:59:59.2799950Z', 'asset_id_base': 'BTC', 'asset_id_quote': 'USD', 'rate': 1595.6336788689919}
# {'time': '2017-05-15T23:59:55.5600000Z', 'asset_id_base': 'ETH', 'asset_id_quote': 'USD', 'rate': 91.7156501346986}
# {'time': '2017-05-15T23:59:59.6393709Z', 'asset_id_base': 'XRP', 'asset_id_quote': 'USD', 'rate': 0.2628375}
# {'time': '2017-05-15T23:59:57.6514098Z', 'asset_id_base': 'LTC', 'asset_id_quote': 'USD', 'rate': 21.953720133811103}
    print('Period end: %s'    % period['time_period_end'])
    print('Time open: %s'     % period['time_open'])
    print('Time close: %s'    % period['time_close'])
    print('Price open: %s'    % period['price_open'])
    print('Price close: %s'   % period['price_close'])
    print('Price low: %s'     % period['price_low'])
    print('Price high: %s'    % period['price_high'])
    print('Volume traded: %s' % period['volume_traded'])
    print('Trades count: %s'  % period['trades_count'])
    print('\n')
# Out:
# execution number : 0
# Period start: 2018-03-25T13:11:00.0000000Z
# Period end: 2018-03-25T13:12:00.0000000Z
# Time open: 2018-03-25T13:11:02.0000000Z
# Time close: 2018-03-25T13:11:52.0000000Z
# Price open: 8490.98
# Price close: 8485.31
# Price low: 8485.31
# Price high: 8492.44
# Volume traded: 1.10357885
# Trades count: 21
#
#
# execution number : 1
# Period start: 2018-03-25T13:10:00.0000000Z
# Period end: 2018-03-25T13:11:00.0000000Z
# Time open: 2018-03-25T13:10:02.0000000Z
# Time close: 2018-03-25T13:10:58.0000000Z
# Price open: 8499.99
# Price close: 8490.98
# Price low: 8483.75
# Price high: 8502.87
# Volume traded: 4.76455817
# Trades count: 34
#
#
# execution number : 2
# Period start: 2018-03-25T13:09:00.0000000Z
# Period end: 2018-03-25T13:10:00.0000000Z
# Time open: 2018-03-25T13:09:01.0000000Z
# Time close: 2018-03-25T13:09:58.0000000Z
# Price open: 8499.29
# Price close: 8492.01
# Price low: 8486.67
# Price high: 8509.93
# Volume traded: 7.45657149
# Trades count: 33
#
#
# execution number : 3
# Period start: 2018-03-25T13:08:00.0000000Z
# Period end: 2018-03-25T13:09:00.0000000Z
# Time open: 2018-03-25T13:08:03.0000000Z
# Time close: 2018-03-25T13:08:59.0000000Z
# Price open: 8486.58
# Price close: 8496.33
# Price low: 8486.57
# Price high: 8499.3
# Volume traded: 0.24266629
# Trades count: 32
#
#
# execution number : 4
# Period start: 2018-03-25T13:07:00.0000000Z
# Period end: 2018-03-25T13:08:00.0000000Z
# Time open: 2018-03-25T13:07:00.0000000Z
# Time close: 2018-03-25T13:07:55.0000000Z
# Price open: 8486.08
# Price close: 8485.47
# Price low: 8485.46
# Price high: 8486.08
# Volume traded: 0.11814704
# Trades count: 23
#
#
# execution number : 5
# Period start: 2018-03-25T13:06:00.0000000Z
# Period end: 2018-03-25T13:07:00.0000000Z
# Time open: 2018-03-25T13:06:01.0000000Z
# Time close: 2018-03-25T13:06:58.0000000Z
# Price open: 8481.38
# Price close: 8485.46
# Price low: 8481.38
# Price high: 8491.27
# Volume traded: 1.08502361
# Trades count: 26
#
#
# execution number : 6
# Period start: 2018-03-25T13:05:00.0000000Z
# Period end: 2018-03-25T13:06:00.0000000Z
# Time open: 2018-03-25T13:05:01.0000000Z
# Time close: 2018-03-25T13:05:56.0000000Z
# Price open: 8480.21
# Price close: 8481.38
# Price low: 8480.2
# Price high: 8495.06
# Volume traded: 0.41775592
# Trades count: 22
#
#
# execution number : 7
# Period start: 2018-03-25T13:04:00.0000000Z
# Period end: 2018-03-25T13:05:00.0000000Z
    ohlcv_latest = api.ohlcv_latest_data('BITSTAMP_SPOT_BTC_USD', {'period_id': '1MIN'})
    return ohlcv_latest

# %%
import pandas as pd

ohlcv_latest  =  api.ohlcv_latest_data('BITSTAMP_SPOT_BTC_USD', {'period_id': '1MIN'})
a             =  ohlcv_lastest_data()
a_df          =  pd.DataFrame(a)

type(a_df)

column_names = list(a_df.columns.values)
print(column_names)

price_close         = a_df[a_df.columns.values[0]]
price_high          = a_df[a_df.columns.values[1]]
price_low           = a_df[a_df.columns.values[2]]
price_open          = a_df[a_df.columns.values[3]]
time_close          = a_df[a_df.columns.values[4]]
time_open           = a_df[a_df.columns.values[5]]    
time_period_end     = a_df[a_df.columns.values[6]]    
time_period_start   = a_df[a_df.columns.values[7]]
trades_count        = a_df[a_df.columns.values[8]]    
volume_traded       = a_df[a_df.columns.values[9]]    
    
    
type(a_df_col_0)
# Out:
# ['price_close', 'price_high', 'price_low', 'price_open', 'time_close', 'time_open', 'time_period_end', 'time_period_start', 'trades_count', 'volume_traded']
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(18, 7), dpi= 80, facecolor='w', edgecolor='k')
price_close.plot(); price_high.plot(); price_low.plot();price_open.plot();
# look at the vaia

# %%
a_df.columns.values
# Out:
# array(['price_close', 'price_high', 'price_low', 'price_open',
#        'time_close', 'time_open', 'time_period_end', 'time_period_start',
#        'trades_count', 'volume_traded'], dtype=object)

# %%
a_df_col_4.plot();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-231-51c855fe6517> in <module>()
# ----> 1 a_df_col_4.plot();
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1925                  yerr=yerr, xerr=xerr,
#    1926                  label=label, secondary_y=secondary_y,
# -> 1927                  **kwds)
#    1928
#    1929
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
# -> 1729     plot_obj.generate()
#    1730     plot_obj.draw()
#    1731     return plot_obj.result
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in generate(self)
#     248     def generate(self):
#     249         self._args_adjust()
# --> 250         self._compute_plot_data()
#     251         self._setup_subplots()
#     252         self._make_plot()
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in _compute_plot_data(self)
#     363         if is_empty:
#     364             raise TypeError('Empty {0!r}: no numeric data to '
# --> 365                             'plot'.format(numeric_data.__class__.__name__))
#     366
#     367         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
import pandas as pd
import numpy  as np

# %matplotlib inline

ts  = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts  = ts.cumsum()
ts.plot()

# %%
ohlcv_latest  =  api.ohlcv_latest_data('BITSTAMP_SPOT_BTC_USD', {'period_id': '1MIN'})
a             =  ohlcv_lastest_data()
a_df          =  pd.DataFrame(a)

# %%
print(dir(pd))
# Out:
# ['Categorical', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'ExcelFile', 'ExcelWriter', 'Expr', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int64Index', 'Interval', 'IntervalIndex', 'MultiIndex', 'NaT', 'Panel', 'Panel4D', 'Period', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseArray', 'SparseDataFrame', 'SparseList', 'SparseSeries', 'Term', 'TimeGrouper', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt64Index', 'WidePanel', '_DeprecatedModule', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_hashtable', '_lib', '_libs', '_np_version_under1p10', '_np_version_under1p11', '_np_version_under1p12', '_np_version_under1p13', '_np_version_under1p14', '_np_version_under1p15', '_tslib', '_version', 'api', 'bdate_range', 'compat', 'concat', 'core', 'crosstab', 'cut', 'date_range', 'datetime', 'datetools', 'describe_option', 'errors', 'eval', 'ewma', 'ewmcorr', 'ewmcov', 'ewmstd', 'ewmvar', 'ewmvol', 'expanding_apply', 'expanding_corr', 'expanding_count', 'expanding_cov', 'expanding_kurt', 'expanding_max', 'expanding_mean', 'expanding_median', 'expanding_min', 'expanding_quantile', 'expanding_skew', 'expanding_std', 'expanding_sum', 'expanding_var', 'factorize', 'get_dummies', 'get_option', 'get_store', 'groupby', 'infer_freq', 'interval_range', 'io', 'isna', 'isnull', 'json', 'lib', 'lreshape', 'match', 'melt', 'merge', 'merge_asof', 'merge_ordered', 'notna', 'notnull', 'np', 'offsets', 'option_context', 'options', 'ordered_merge', 'pandas', 'parser', 'period_range', 'pivot', 'pivot_table', 'plot_params', 'plotting', 'pnow', 'qcut', 'read_clipboard', 'read_csv', 'read_excel', 'read_feather', 'read_fwf', 'read_gbq', 'read_hdf', 'read_html', 'read_json', 'read_msgpack', 'read_parquet', 'read_pickle', 'read_sas', 'read_sql', 'read_sql_query', 'read_sql_table', 'read_stata', 'read_table', 'reset_option', 'rolling_apply', 'rolling_corr', 'rolling_count', 'rolling_cov', 'rolling_kurt', 'rolling_max', 'rolling_mean', 'rolling_median', 'rolling_min', 'rolling_quantile', 'rolling_skew', 'rolling_std', 'rolling_sum', 'rolling_var', 'rolling_window', 'scatter_matrix', 'set_eng_float_format', 'set_option', 'show_versions', 'stats', 'test', 'testing', 'timedelta_range', 'to_datetime', 'to_msgpack', 'to_numeric', 'to_pickle', 'to_timedelta', 'tools', 'tseries', 'tslib', 'unique', 'util', 'value_counts', 'wide_to_long']

# %%
type(a)
# Out:
# list

# %%
type(a[0])
# Out:
# dict

# %%
a[0].keys()
# Out:
# dict_keys(['time_period_start', 'time_period_end', 'time_open', 'time_close', 'price_open', 'price_high', 'price_low', 'price_close', 'volume_traded', 'trades_count'])

# %%
a[0].values()
# Out:
# dict_values(['2018-03-25T13:18:00.0000000Z', '2018-03-25T13:19:00.0000000Z', '2018-03-25T13:18:00.0000000Z', '2018-03-25T13:18:06.0000000Z', 8503.41, 8505.23, 8496.75, 8505.23, 2.73212947, 10])

# %%
print(period_ids)
# Out:
# ['1SEC', '2SEC', '3SEC', '4SEC', '5SEC', '6SEC', '10SEC', '15SEC', '20SEC', '30SEC', '1MIN', '2MIN', '3MIN', '4MIN', '5MIN', '6MIN', '10MIN', '15MIN', '20MIN', '30MIN', '1HRS', '2HRS', '3HRS', '4HRS', '6HRS', '8HRS', '12HRS', '1DAY', '2DAY', '3DAY', '5DAY', '7DAY', '10DAY', '1MTH', '2MTH', '3MTH', '4MTH', '6MTH', '1YRS', '2YRS', '3YRS', '4YRS', '5YRS']
