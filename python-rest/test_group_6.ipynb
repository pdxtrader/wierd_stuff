# %%
from    coinapi_v1 import CoinAPIv1
import  datetime
from    datetime  import date
from    datetime  import datetime
from    datetime  import timedelta
from    tqdm      import tqdm

test_key      =  'B77ED0B6-F44D-4186-A6BB-5AB92FAA3793'

api           = None
exchanges     = None
assets        = None
symbols       = None
periods       = None

asset_ids     = []
exchange_ids  = []
symbol_ids    = []
period_ids    = []

start_of_2015              = date(2015, 1, 1)
start_of_2016              = date(2016, 1, 1)
start_of_2017              = date(2017, 1, 1)
start_of_2018              = date(2018, 1, 1)
datetime__now              = datetime.now()
datetime__now_iso          = datetime__now.isoformat()
date__today                = date.today()
date__today_iso            = date__today.isoformat()
date__yesterday            = date__today - timedelta(1)
date__two_days_ago         = date__today - timedelta(2)
date__three_days_ago       = date__today - timedelta(3)
date__four_days_ago        = date__today - timedelta(4)
date__five_days_ago        = date__today - timedelta(5)
date__six_days_ago         = date__today - timedelta(6)
date__week_ago             = date__today - timedelta(7)
date__mounth_ago           = date__today - timedelta(30)
datetime__now              = datetime.now()
datetime__yesterday        = datetime__now - timedelta(1)
datetime__two_days_ago     = datetime__now - timedelta(2)
datetime__three_days_ago   = datetime__now - timedelta(3)
datetime__four_days_ago    = datetime__now - timedelta(4)
datetime__five_days_ago    = datetime__now - timedelta(5)
datetime__six_days_ago     = datetime__now - timedelta(6)
datetime__week_ago         = datetime__now - timedelta(7)
datetime__mounth_ago       = datetime__now - timedelta(30)
datetime__hour_ago         = datetime__now - timedelta(hours = 1)
datetime__two_hours_ago    = datetime__now - timedelta(hours = 2)
datetime__three_hours_ago  = datetime__now - timedelta(hours = 3)
datetime__six_hours_ago    = datetime__now - timedelta(hours = 6)
datetime__twelve_hours_ago = datetime__now - timedelta(hours = 12)


def update_ids():
    global assets
    global exchanges
    global symbols
    global periods
    global asset_ids
    global exchange_ids
    global symbol_ids
    global period_ids
    for ii in tqdm(range(0, 4), desc=  '[Updating _ids variables                ]'):
        if ii == 0:
            for asset in assets:
                asset_ids.append(asset['asset_id'])
        if ii == 1:
            for exchange in exchanges:
                exchange_ids.append(exchange['exchange_id'])
        if ii == 2:
            for symbol in symbols:
                symbol_ids.append(symbol['symbol_id'])
        if ii == 3:
            for period in periods:
                period_ids.append(period['period_id'])

def update_coinapi():
    global api 
    global exchanges
    global assets
    global symbols
    global periods
    for ii in tqdm(range(0, 5),desc = '[Updating Meta Data from Coinapi        ]' ):    
        if ii == 0:
            api           = CoinAPIv1(test_key)
        elif ii == 1:
            exchanges     = api.metadata_list_exchanges()
        elif ii == 2:
            assets        = api.metadata_list_assets()
        elif ii == 3:
            symbols       = api.metadata_list_symbols()
        elif ii == 4:
            periods       = api.ohlcv_list_all_periods()

def update_time():
    global datetime__now             
    global datetime__now_iso          
    global date__today                
    global date__today_iso            
    global date__today
    global date__yesterday            
    global date__two_days_ago         
    global date__three_days_ago      
    global date__four_days_ago      
    global date__five_days_ago      
    global date__six_days_ago       
    global date__week_ago           
    global date__mounth_ago       
    global datetime__now           
    global datetime__yesterday       
    global datetime__two_days_ago     
    global datetime__three_days_ago  
    global datetime__four_days_ago   
    global datetime__five_days_ago  
    global datetime__six_days_ago    
    global datetime__week_ago        
    global datetime__mounth_ago    
    global datetime__hour_ago         
    global datetime__two_hours_ago  
    global datetime__three_hours_ago 
    global datetime__six_hours_ago   
    global datetime__twelve_hours_ago    
    for ii in tqdm(range(0,28), desc='[Updating time related variables        ]'):
        if ii == 0:
            datetime__now              = datetime.now()
        elif ii == 1:
            datetime__now_iso          = datetime__now.isoformat()
        elif ii == 2:
            datetime__now_iso          = datetime__now.isoformat()       
        elif ii == 3:
            datetime__now_iso          = datetime__now.isoformat()
        elif ii == 4:
             date__today                = date.today()
        elif ii == 5:
            date__today_iso            = date__today.isoformat()
        elif ii == 6:
            date__yesterday            = date__today - timedelta(1)
        elif ii == 7:
            date__two_days_ago         = date__today - timedelta(2) 
        elif ii == 8:
            date__three_days_ago       = date__today - timedelta(3)
        elif ii == 9:
            date__four_days_ago        = date__today - timedelta(4)
        elif ii == 10:
            date__five_days_ago        = date__today - timedelta(5)
        elif ii == 11:
            date__six_days_ago         = date__today - timedelta(6)
        elif ii == 12:
            date__week_ago             = date__today - timedelta(7)
        elif ii == 13:
            date__mounth_ago           = date__today - timedelta(30)
        elif ii == 14:
            datetime__now              = datetime.now()
        elif ii == 15:
            datetime__yesterday        = datetime__now - timedelta(1)
        elif ii == 16:
            datetime__two_days_ago     = datetime__now - timedelta(2)
        elif ii == 17:
            datetime__three_days_ago   = datetime__now - timedelta(3)
        elif ii == 18:
            datetime__four_days_ago    = datetime__now - timedelta(4)
        elif ii == 19:
            datetime__five_days_ago    = datetime__now - timedelta(5)
        elif ii == 20:
            datetime__six_days_ago     = datetime__now - timedelta(6)
        elif ii == 21:
            datetime__week_ago         = datetime__now - timedelta(7)
        elif ii == 22:
            datetime__mounth_ago       = datetime__now - timedelta(30)
        elif ii == 23:
            datetime__hour_ago         = datetime__now - timedelta(hours = 1)
        elif ii == 24:
            datetime__two_hours_ago    = datetime__now - timedelta(hours = 2)
        elif ii == 25:
            datetime__three_hours_ago  = datetime__now - timedelta(hours = 3)
        elif ii == 26:
            datetime__six_hours_ago    = datetime__now - timedelta(hours = 6)
        elif ii == 27:
            datetime__twelve_hours_ago = datetime__now - timedelta(hours = 12)    
                  
def update_all():
    for ii in tqdm(range(0, 3),desc = '[Updating all                           ]' ):    
        if ii == 0:
            update_coinapi()             
        elif ii == 1:
            update_ids()
        elif ii == 3:
            update_time()
    
def current_exchange_rate(asset_1, asset_2):
    from datetime import date
    global api
    result = {}
    return api.exchange_rates_get_specific_rate(asset_1, asset_2)

def exchange_rate(asset_1, asset_2, exchange_date = date.today()):
    from datetime import date
    global api
    exchange_date_iso = exchange_date.isoformat()
    return api.exchange_rates_get_specific_rate(str(asset_1), str(asset_2), {'time': exchange_date_iso})

def all_current_exchange_rates(asset_1):
    global api
    return api.exchange_rates_get_all_current_rates(asset_1)

# %%
# testing update_all() situation
update_all()
print(str(datetime__now) + '  '  + str(datetime__three_hours_ago))
# print(asset_ids)
print(datetime__now) 
print(api)
# seems ok
# Out:
# [Updating all                           ]:   0%|          | 0/3 [00:00<?, ?it/s]
# [Updating Meta Data from Coinapi        ]:   0%|          | 0/5 [00:00<?, ?it/s]
# [Updating Meta Data from Coinapi        ]:  40%|████      | 2/5 [00:00<00:00,  4.45it/s]
# [Updating Meta Data from Coinapi        ]:  60%|██████    | 3/5 [00:01<00:00,  2.21it/s]
# [Updating Meta Data from Coinapi        ]:  80%|████████  | 4/5 [00:06<00:01,  1.72s/it]
# [Updating Meta Data from Coinapi        ]: 100%|██████████| 5/5 [00:07<00:00,  1.45s/it]
# [Updating all                           ]:  33%|███▎      | 1/3 [00:07<00:14,  7.28s/it]
# [Updating _ids variables                ]:   0%|          | 0/4 [00:00<?, ?it/s]
# [Updating all                           ]: 100%|██████████| 3/3 [00:07<00:00,  2.43s/it]]
# 2018-03-24 21:34:29.126377  2018-03-24 18:34:29.126377
# 2018-03-24 21:34:29.126377
# <coinapi_v1.CoinAPIv1 object at 0x7ff7c11b06d8>

# %%
print(current_exchange_rate('BTC', 'USD'))
print(current_exchange_rate('ETH', 'USD'))
print(current_exchange_rate('XRP', 'USD'))
print(current_exchange_rate('LTC', 'USD'))
print(current_exchange_rate('USDT', 'USD'))

print(exchange_rate('BTC', 'USD',  exchange_date = date(2017,5,16)))
print(exchange_rate('ETH', 'USD',  exchange_date = date(2017,5,16)))
print(exchange_rate('XRP', 'USD',  exchange_date = date(2017,5,16)))
print(exchange_rate('LTC', 'USD',  exchange_date = date(2017,5,16)))
print(exchange_rate('USDT', 'USD', exchange_date = date(2017,5,16)))

a = date(2017,11,20)
print(exchange_rate('BTC', 'USD',  exchange_date = a))
print(exchange_rate('ETH', 'USD',  exchange_date = a))
print(exchange_rate('XRP', 'USD',  exchange_date = a))
print(exchange_rate('LTC', 'USD',  exchange_date = a))
print(exchange_rate('USDT', 'USD', exchange_date = a))
# Out:
# {'time': '2018-03-24T20:34:44.1006572Z', 'asset_id_base': 'BTC', 'asset_id_quote': 'USD', 'rate': 8936.678471386302}
# {'time': '2018-03-24T20:34:44.3662841Z', 'asset_id_base': 'ETH', 'asset_id_quote': 'USD', 'rate': 537.4918774185849}
# {'time': '2018-03-24T20:34:44.2569046Z', 'asset_id_base': 'XRP', 'asset_id_quote': 'USD', 'rate': 0.6501910650579217}
# {'time': '2018-03-24T20:34:44.7881524Z', 'asset_id_base': 'LTC', 'asset_id_quote': 'USD', 'rate': 165.25270869831857}
# {'time': '2018-03-24T20:32:30.9843351Z', 'asset_id_base': 'USDT', 'asset_id_quote': 'USD', 'rate': 1.00075}
# {'time': '2017-05-15T23:59:59.2799950Z', 'asset_id_base': 'BTC', 'asset_id_quote': 'USD', 'rate': 1595.6336788689919}
# {'time': '2017-05-15T23:59:55.5600000Z', 'asset_id_base': 'ETH', 'asset_id_quote': 'USD', 'rate': 91.7156501346986}
# {'time': '2017-05-15T23:59:59.6393709Z', 'asset_id_base': 'XRP', 'asset_id_quote': 'USD', 'rate': 0.2628375}
# {'time': '2017-05-15T23:59:57.6514098Z', 'asset_id_base': 'LTC', 'asset_id_quote': 'USD', 'rate': 21.953720133811103}
# {'time': '2017-05-15T23:59:51.2744001Z', 'asset_id_base': 'USDT', 'asset_id_quote': 'USD', 'rate': 0.979425}
# {'time': '2017-11-19T23:59:59.6018960Z', 'asset_id_base': 'BTC', 'asset_id_quote': 'USD', 'rate':
575.1684464424666}, {'time': '2018-03-24T20:37:27.5069861Z', 'asset_id_quote': 'INR', 'rate': 10738.913006988683}, {'time': '2018-03-24T20:37:27.6944858Z', 'asset_id_quote': 'JPY', 'rate': 17360.495589392707}, {'time': '2018-03-24T20:37:27.8194905Z', 'asset_id_quote': 'KRW', 'rate': 178007.30139177677}, {'time': '2018-03-24T20:35:59.1720000Z', 'asset_id_quote': 'LCC', 'rate': 582.9985949733862}, {'time': '2018-03-24T20:36:27.3800647Z', 'asset_id_quote': 'LINDA', 'rate': -1.0}, {'time': '2018-03-24T20:37:28.1007400Z', 'asset_id_quote': 'LTC', 'rate': 1.0}, {'time': '2018-03-24T20:32:45.7612901Z', 'asset_id_quote': 'MCAP', 'rate': -1.0}, {'time': '2018-03-24T20:36:45.1070000Z', 'asset_id_quote': 'MLM', 'rate': 2124.743702790851}, {'time': '2018-03-24T20:37:28.6476171Z', 'asset_id_quote': 'MXN', 'rate': 3061.6238884194613}, {'time': '2018-03-24T20:37:28.6476171Z', 'asset_id_quote': 'MYR', 'rate': 647.1715501626162}, {'time': '2018-03-24T20:35:52.8060000Z', 'asset_id_quote': 'NEO', 'rate': 2.4174585}, {'time': '2018-03-24T20:37:28.6476171Z', 'asset_id_quote': 'NOK', 'rate': 1280.7613961297386}, {'time': '2018-03-24T20:37:28.6476171Z', 'asset_id_quote': 'NZD', 'rate': 227.79796278235042}, {'time': '2018-03-24T20:37:29.3351142Z', 'asset_id_quote': 'PHP', 'rate': 8649.471519179471}, {'time': '2018-03-24T20:37:29.4444943Z', 'asset_id_quote': 'PLN', 'rate': 565.5073721280365}, {'time': '2018-03-24T20:37:08.1500000Z', 'asset_id_quote': 'PNX', 'rate': 8195.041999590248}, {'time': '2018-03-24T20:37:30.1163770Z', 'asset_id_quote': 'RON', 'rate': 623.9555336314028}, {'time': '2018-03-24T20:37:30.1163770Z', 'asset_id_quote': 'RUB', 'rate': 9438.789319262018}, {'time': '2018-03-24T20:36:40.2084653Z', 'asset_id_quote': 'RUR', 'rate': 9211.37475}, {'time': '2018-03-24T20:37:30.1163770Z', 'asset_id_quote': 'SEK', 'rate': 1364.098197833714}, ...

# %%
ohlcv_latest = api.ohlcv_latest_data('BITSTAMP_SPOT_BTC_USD', {'period_id': '1MIN'})
for period in ohlcv_latest:
    print('Period start: %s'  % period['time_period_start'])
    print('Period end: %s'    % period['time_period_end'])
    print('Time open: %s'     % period['time_open'])
    print('Time close: %s'    % period['time_close'])
    print('Price open: %s'    % period['price_open'])
    print('Price close: %s'   % period['price_close'])
    print('Price low: %s'     % period['price_low'])
    print('Price high: %s'    % period['price_high'])
    print('Volume traded: %s' % period['volume_traded'])
    print('Trades count: %s'  % period['trades_count'])
    print('\n')
# Out:
# Period start: 2018-03-24T20:43:00.0000000Z
# Period end: 2018-03-24T20:44:00.0000000Z
# Time open: 2018-03-24T20:43:21.0000000Z
# Time close: 2018-03-24T20:43:48.0000000Z
# Price open: 8928.47
# Price close: 8929.14
# Price low: 8928.47
# Price high: 8929.15
# Volume traded: 0.32722842
# Trades count: 4
#
#
# Period start: 2018-03-24T20:42:00.0000000Z
# Time close: 2018-03-24T19:06:43.0000000Z
# Price open: 8914.98
# Price close: 8914.98
# Price low: 8908.0
# Price high: 8914.98
# Volume traded: 0.22911665
# Trades count: 4
#
#
# Period start: 2018-03-24T19:05:00.0000000Z
# Period end: 2018-03-24T19:06:00.0000000Z
# Time open: 2018-03-24T19:05:11.0000000Z
# Time close: 2018-03-24T19:05:54.0000000Z
# Price open: 8898.41
# Price close: 8906.99
# Price low: 8898.41
# Price high: 8906.99
# Volume traded: 0.08442101
# Trades count: 4
#
#
# Period start: 2018-03-24T19:04:00.0000000Z
# Period end: 2018-03-24T19:05:00.0000000Z
# Time open: 2018-03-24T19:04:13.0000000Z
# Time close: 2018-03-24T19:04:59.0000000Z
# Price open: 8900.89
# Price close: 8898.31
# Price low: 8897.91
# Price high: 8900.89
# Volume traded: 0.14590566
# Trades count: 4
#
#
# Period start: 2018-03-24T19:03:00.0000000Z
# Period end: 2018-03-24T19:04:00.0000000Z
# Time open: 2018-03-24T19:03:24.0000000Z
# Time close: 2018-03-24T19:03:24.0000000Z
# Price open: 8900.9
# Price close: 8900.9
# Price low: 8900.9
# Price high: 8900.9
# Volume traded: 0.00854058
# Trades count: 1
#
#
# Period start: 2018-03-24T19:02:00.0000000Z
# Period end: 2018-03-24T19:03:00.0000000Z
# Time open: 2018-03-24T19:02:03.0000000Z
# Time close: 2018-03-24T19:02:54.0000000Z
# Price open: 8896.41
# Price close: 8900.26
# Price low: 8895.31
# Price high: 8900.27
# Volume traded: 3.04082089
# Trades count: 6
#
#
# Period start: 2018-03-24T19:01:00.0000000Z
# Period end: 2018-03-24T19:02:00.0000000Z
# Time open: 2018-03-24T19:01:08.0000000Z
# Time close: 2018-03-24T19:01:59.0000000Z
# Price open: 8910.6
# Price close: 8887.1
# Price low: 8887.1
# Price high: 8919.9
# Volume traded: 3.82226189
# Trades count: 20
#
#
# Period start: 2018-03-24T19:00:00.0000000Z
# Period end: 2018-03-24T19:01:00.0000000Z
# Time open: 2018-03-24T19:00:22.0000000Z
# Time close: 2018-03-24T19:00:59.0000000Z
# Price open: 8922.98
# Price close: 8912.39
# Price low: 8912.39
# Price high: 8924.02
# Volume traded: 28.77915007
# Trades count: 39
#
#
# Period start: 2018-03-24T18:59:00.0000000Z
# Period end: 2018-03-24T19:00:00.0000000Z
# Time open: 2018-03-24T18:59:09.0000000Z
# Time close: 2018-03-24T18:59:13.0000000Z
# Price open: 8924.06
# Price close: 8925.61
# Price low: 8924.06
# Price high: 8925.61
# Volume traded: 0.59
# Trades count: 2

# %%
print(period_ids)
# Out:
# ['1SEC', '2SEC', '3SEC', '4SEC', '5SEC', '6SEC', '10SEC', '15SEC', '20SEC', '30SEC', '1MIN', '2MIN', '3MIN', '4MIN', '5MIN', '6MIN', '10MIN', '15MIN', '20MIN', '30MIN', '1HRS', '2HRS', '3HRS', '4HRS', '6HRS', '8HRS', '12HRS', '1DAY', '2DAY', '3DAY', '5DAY', '7DAY', '10DAY', '1MTH', '2MTH', '3MTH', '4MTH', '6MTH', '1YRS', '2YRS', '3YRS', '4YRS', '5YRS']
